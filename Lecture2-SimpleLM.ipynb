# %% [markdown]
# <a href="https://colab.research.google.com/github/ab-sa/Statistical-Machine-Learning-2/blob/main/Lecture2-SimpleLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import some libraries

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import Credit data

# %%
Credit = pd.read_csv('Credit.csv')

# %% [markdown]
# Top a few rows of Credit data

# %%
Credit.head()
# Out:
#    ID   Income  Limit  Rating  ...  Student  Married  Ethnicity Balance
# 0   1   14.891   3606     283  ...       No      Yes  Caucasian     333
# 1   2  106.025   6645     483  ...      Yes      Yes      Asian     903
# 2   3  104.593   7075     514  ...       No       No      Asian     580
# 3   4  148.924   9504     681  ...       No       No      Asian     964
# 4   5   55.882   4897     357  ...       No      Yes  Caucasian     331
#
# [5 rows x 12 columns]

# %% [markdown]
# Scatter plot matrix

# %%
pd.plotting.scatter_matrix(Credit).get_plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-6358038eff3b> in <module>()
# ----> 1 pd.plotting.scatter_matrix(Credit).get_plot()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get_plot'

# %%
sns.pairplot(Credit)

# %% [markdown]
# Fit a simple linear regression model

# %%
X = Credit[['Income']]
y = Credit['Balance']
reg = LinearRegression().fit(X, y)

# %% [markdown]
# Regression coefficient estimates

# %%
print('R^2: ' + str(reg.score(X, y) * 100))
print('Intercept: ' + str(reg.intercept_))
print('Slope: ' + str(reg.coef_))
# Out:
# R^2: 21.497731013240497
# Intercept: 246.5147505914033
# Slope: [6.04836341]

# %%
# Obtain prediction values
preds = reg.predict(X)

# The coefficients
print("Coefficients: \n", reg.intercept_, reg.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y, preds))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y, preds))
# Out:
# Coefficients:
#  246.5147505914033 [6.04836341]
# Mean squared error: 165521.86
# Coefficient of determination: 0.21

# %% [markdown]
# Visualize the fitted regression line

# %%
plt.scatter(X, y, color = "black")
plt.plot(X, preds, color = "blue", linewidth = 3)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
sns.regplot(x = "Income", y = "Balance", data = Credit)
